# %% [markdown]
# # Materialien zu <i>zufall</i>
#
# Autor: Holger Böttcher - hbomat@posteo.de
#
# ## Aufgaben 1 - Baumdiagramme

# %% [markdown]
# <br>
# <i>Die Aufgabe wurde entnommen aus <br>
# <br>
# V. Warstat<br>
# Mathematik<br>
# Stochastik<br>
# R. Oldenbourg Verlag 1993<br>
# S. 56 Aufgabe 2
# </i>
# <br>
# <br>
# <br>
# In einer Urne befinden sich eine goldene, zwei rote und drei schwarze Kugeln. '<br>
# Man zieht nacheinander drei Kugeln
# <br>
# <br>
# a) ohne Zurücklegen&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; b) mit Zurücklegen  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  nach jedem Zug
# <br>
# <br>
# Zeichnen Sie jeweils ein Baumdiagramm, und geben Sie die Ergebnismenge an. <br>
# Zählen Sie die Ergebnisse ab
# <br><br>

# %%
# %run zufall/start

# %% [markdown]
# ### Zu a)

# %%
gold, rot, schwarz = symbols('g r s')

u1 = Urne( [ (gold, 1), (rot, 2), (schwarz, 3) ], 3, w=nein )
u1
# Out:
# Urne(Stufen=3, ohne Wiederholung , mit Anordnung)

# %%
u1.baum

# %%
u1.omega
# Out:
# set([grr, grs, gsr, gss, rgr, rgs, rrg, rrs, rsg, rsr, rss, sgr, sgs, srg, srr
# , srs, ssg, ssr, sss])

# %%
u1.n_omega
# Out:
# 19

# %% [markdown]
# ### Zu b)

# %%
gold, rot, schwarz = symbols('gold rot schwarz')

u2 = Urne( [ (gold, 1), (rot, 2), (schwarz, 3) ], 3 )
u2
# Out:
# Urne(Stufen=3, mit Wiederholung , mit Anordnung)

# %%
u2.baum

# %%
u2.omega
# Out:
# set([goldgoldgold, goldgoldrot, goldgoldschwarz, goldrotgold, goldrotrot, gold
# rotschwarz, goldschwarzgold, goldschwarzrot, goldschwarzschwarz, rotgoldgold,
# rotgoldrot, rotgoldschwarz, rotrotgold, rotrotrot, rotrotschwarz, rotschwarzgo
# ld, rotschwarzrot, rotschwarzschwarz, schwarzgoldgold, schwarzgoldrot, schwarz
# goldschwarz, schwarzrotgold, schwarzrotrot, schwarzrotschwarz, schwarzschwarzg
# old, schwarzschwarzrot, schwarzschwarzschwarz])

# %%
u2.n_omega
# Out:
# 27
