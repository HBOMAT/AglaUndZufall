# %% [markdown]
# # Materialien zu <i>agla</i>
#
# Autor: Holger Böttcher - hbomat@posteo.de
#
# ## Archimedische Körper

# %% [markdown]
# ### Ikosidodekaederstumpf

# %% [markdown]
# (Großes Rhombenikosidodekaeder)
#
# Flächenfolge in einer Ecke  (4, 6, 10)
# <br><br>

# %%
# %run agla/start

# %%
# Die Koordinaten der Eckpunkte sind näherungsweise definiert

# Erzeugung des Körpers über seine Seitenflächen

UMG.SIMPL = False

p0=v(0,0,0.655694)
p1=v(0.1709448,0,0.6330181)
p2=v(-0.00300786,0.17091815,0.6330181)
p3=v(-0.1437384,-0.0925275,0.6330181)
p4=v(0.16793725,0.17091815,0.61034285)
p5=v(0.3038009,-0.0925275,0.57365295)
p6=v(-0.14975415,0.24930945,0.58766695)
p7=v(-0.2053675,-0.2422407,0.57365295)
p8=v(-0.290485,-0.01413698,0.58766695)
p9=v(0.29778515,0.24930945,0.5283018)
p10=v(0.3478215,-0.2422407,0.5002738)
p11=v(0.43364945,-0.01413698,0.49161255)
p12=v(-0.21625045,0.37614785,0.49161255)
p13=v(-0.2934932,0.1567813,0.5649917)
p14=v(-0.3521141,-0.16385005,0.5283018)
p15=v(-0.1613469,-0.3919539,0.5002738)
p16=v(0.3369392,0.37614785,0.41823275)
p17=v(0.43064125,0.1567813,0.46893665)
p18=v(0.47767005,-0.16385005,0.41823275)
p19=v(0.2861924,-0.3919539,0.440908)
p20=v(-0.35998885,0.28362035,0.46893665)
p21=v(-0.1770964,0.5029869,0.38154285)
p22=v(-0.4548401,-0.23517195,0.4095715)
p23=v(-0.0284908,-0.4844814,0.440908)
p24=v(-0.2640729,-0.4632758,0.38154285)
p25=v(0.4697953,0.28362035,0.3588676)
p26=v(0.27044355,0.5029869,0.3221777)
p27=v(0.54588885,-0.23517195,0.2768272)
p28=v(0.142454,-0.4844814,0.41823275)
p29=v(0.35441185,-0.4632758,0.29950245)
p30=v(-0.4645732,0.31793125,0.33619235)
p31=v(-0.04724798,0.58137755,0.29950245)
p32=v(-0.28168075,0.5372978,0.24879855)
p33=v(-0.55942445,-0.20086105,0.2768272)
p34=v(-0.41081885,-0.38488515,0.33619235)
p35=v(-0.1312168,-0.55580395,0.3221777)
p36=v(0.53615575,0.31793125,0.2034474)
p37=v(0.12369695,0.58137755,0.2768272)
p38=v(0.33680335,0.5372978,0.16675815)
p39=v(0.6122493,-0.20086105,0.121407)
p40=v(0.4842604,-0.38488515,0.21746205)
p41=v(0.21067345,-0.55580395,0.2768272)
p42=v(-0.5672992,0.24660935,0.21746205)
p43=v(-0.4254198,0.4447703,0.2261233)
p44=v(-0.15183285,0.6156891,0.16675815)
p45=v(-0.51540385,-0.35057425,0.2034474)
p46=v(-0.6259201,-0.074022,0.18077215)
p47=v(-0.06299735,-0.62712585,0.18077215)
p48=v(0.60437455,0.24660935,0.06204165)
p49=v(0.46965945,0.4447703,0.10739235)
p50=v(0.1900574,0.6156891,0.121407)
p51=v(0.5506202,-0.35057425,0.06204165)
p52=v(0.651404,-0.074022,0.01133776)
p53=v(0.10794745,-0.62712585,0.15809625)
p54=v(-0.52814515,0.3734484,0.10739235)
p55=v(-0.6289283,0.09689615,0.15809625)
p56=v(-0.0854724,0.65,0.01133776)
p57=v(-0.5378789,-0.3734484,0.0340132)
p58=v(-0.64839515,-0.09689615,0.01133776)
p59=v(-0.0854724,-0.65,0.01133776)
p60=v(0.5378789,0.3734484,-0.0340132)
p61=v(0.64839515,0.09689615,-0.01133776)
p62=v(0.0854724,0.65,-0.01133776)
p63=v(0.52814515,-0.3734484,-0.10739235)
p64=v(0.6289283,-0.09689615,-0.15809625)
p65=v(0.0854724,-0.65,-0.01133776)
p66=v(-0.5506202,0.35057425,-0.06204165)
p67=v(-0.651404,0.074022,-0.01133776)
p68=v(-0.10794745,0.62712585,-0.15809625)
p69=v(-0.46965945,-0.4447703,-0.10739235)
p70=v(-0.60437455,-0.24660935,-0.06204165)
p71=v(-0.1900574,-0.6156891,-0.121407)
p72=v(0.51540385,0.35057425,-0.2034474)
p73=v(0.6259201,0.074022,-0.18077215)
p74=v(0.06299735,0.62712585,-0.18077215)
p75=v(0.4254198,-0.4447703,-0.2261233)
p76=v(0.5672992,-0.24660935,-0.21746205)
p77=v(0.15183285,-0.6156891,-0.16675815)
p78=v(-0.4842604,0.38488515,-0.21746205)
p79=v(-0.6122493,0.20086105,-0.121407)
p80=v(-0.21067345,0.55580395,-0.2768272)
p81=v(-0.53615575,-0.31793125,-0.2034474)
p82=v(-0.33680335,-0.5372978,-0.16675815)
p83=v(-0.12369695,-0.58137755,-0.2768272)
p84=v(0.41081885,0.38488515,-0.33619235)
p85=v(0.55942445,0.20086105,-0.2768272)
p86=v(0.1312168,0.55580395,-0.3221777)
p87=v(0.4645732,-0.31793125,-0.33619235)
p88=v(0.28168075,-0.5372978,-0.24879855)
p89=v(0.04724798,-0.58137755,-0.29950245)
p90=v(-0.54588885,0.23517195,-0.2768272)
p91=v(-0.35441185,0.4632758,-0.29950245)
p92=v(-0.142454,0.4844814,-0.41823275)
p93=v(-0.4697953,-0.28362035,-0.3588676)
p94=v(-0.27044355,-0.5029869,-0.3221777)
p95=v(0.4548401,0.23517195,-0.4095715)
p96=v(0.2640729,0.4632758,-0.38154285)
p97=v(0.0284908,0.4844814,-0.440908)
p98=v(0.35998885,-0.28362035,-0.46893665)
p99=v(0.1770964,-0.5029869,-0.38154285)
p100=v(-0.47767005,0.16385005,-0.41823275)
p101=v(-0.2861924,0.3919539,-0.440908)
p102=v(-0.43064125,-0.1567813,-0.46893665)
p103=v(-0.3369392,-0.37614785,-0.41823275)
p104=v(0.3521141,0.16385005,-0.5283018)
p105=v(0.1613469,0.3919539,-0.5002738)
p106=v(0.2934932,-0.1567813,-0.5649917)
p107=v(0.21625045,-0.37614785,-0.49161255)
p108=v(-0.43364945,0.01413698,-0.49161255)
p109=v(-0.3478215,0.2422407,-0.5002738)
p110=v(-0.29778515,-0.24930945,-0.5283018)
p111=v(0.290485,0.01413698,-0.58766695)
p112=v(0.2053675,0.2422407,-0.57365295)
p113=v(0.14975415,-0.24930945,-0.58766695)
p114=v(-0.3038009,0.0925275,-0.57365295)
p115=v(-0.16793725,-0.17091815,-0.61034285)
p116=v(0.1437384,0.0925275,-0.6330181)
p117=v(0.00300786,-0.17091815,-0.6330181)
p118=v(-0.1709448,0,-0.6330181)
p119=v(0,0,-0.655694)

vierecke = [
Koerper(p0,  p1,  p4,  p2,p0),
Koerper(p3,  p8,  p14, p7,p3),
Koerper(p5,  p10, p18, p11,p5),
Koerper(p6,  p12, p20, p13,p6),
Koerper(p9,  p17, p25, p16,p9),
Koerper(p15, p24, p35, p23,p15),
Koerper(p19, p28, p41, p29,p19),
Koerper(p21, p31, p44, p32,p21),
Koerper(p22, p33, p45, p34,p22),
Koerper(p26, p38, p50, p37,p26),
Koerper(p27, p40, p51, p39,p27),
Koerper(p30, p43, p54, p42,p30),
Koerper(p36, p48, p60, p49,p36),
Koerper(p46, p55, p67, p58,p46),
Koerper(p47, p59, p65, p53,p47),
Koerper(p52, p64, p73, p61,p52),
Koerper(p56, p62, p74, p68,p56),
Koerper(p57, p70, p81, p69,p57),
Koerper(p63, p75, p87, p76,p63),
Koerper(p66, p78, p90, p79,p66),
Koerper(p71, p82, p94, p83,p71),
Koerper(p72, p85, p95, p84,p72),
Koerper(p77, p89, p99, p88,p77),
Koerper(p80, p92, p101,p91,p80),
Koerper(p86, p96, p105,p97,p86),
Koerper(p93, p102,p110,p103,p93),
Koerper(p98, p107,p113,p106,p98),
Koerper(p100,p109,p114,p108,p100),
Koerper(p104,p111,p116,p112,p104),
Koerper(p115,p118,p119,p117,p115)
] 

sechsecke = [
Koerper(p0,  p2,  p6,  p13, p8,  p3,p0),
Koerper(p1,  p5,  p11, p17, p9,  p4,p1),
Koerper(p7,  p14, p22, p34, p24, p15,p7),
Koerper(p10, p19, p29, p40, p27, p18,p10),
Koerper(p12, p21, p32, p43, p30, p20,p12),
Koerper(p16, p25, p36, p49, p38, p26,p16),
Koerper(p23, p35, p47, p53, p41, p28,p23),
Koerper(p31, p37, p50, p62, p56, p44,p31),
Koerper(p33, p46, p58, p70, p57, p45,p33),
Koerper(p39, p51, p63, p76, p64, p52,p39),
Koerper(p42, p54, p66, p79, p67, p55,p42),
Koerper(p48, p61, p73, p85, p72, p60,p48),
Koerper(p59, p71, p83, p89, p77, p65,p59),
Koerper(p68, p74, p86, p97, p92, p80,p68),
Koerper(p69, p81, p93, p103,p94, p82,p69),
Koerper(p75, p88, p99, p107,p98, p87,p75),
Koerper(p78, p91, p101,p109,p100,p90,p78),
Koerper(p84, p95, p104,p112,p105,p96,p84),
Koerper(p102,p108,p114,p118,p115,p110,p102),
Koerper(p106,p113,p117,p119,p116,p111,p106)
] 

zehnecke = [
Koerper(p0, p3, p7,  p15, p23, p28, p19, p10, p5,  p1,p0),
Koerper(p2, p4, p9,  p16, p26, p37, p31, p21, p12, p6,p2),
Koerper(p8, p13,p20, p30, p42, p55, p46, p33, p22, p14,p8),
Koerper(p11,p18,p27, p39, p52, p61, p48, p36, p25, p17,p11),
Koerper(p24,p34,p45, p57, p69, p82, p71, p59, p47, p35,p24),
Koerper(p29,p41,p53, p65, p77, p88, p75, p63, p51, p40,p29),
Koerper(p32,p44,p56, p68, p80, p91, p78, p66, p54, p43,p32),
Koerper(p38,p49,p60, p72, p84, p96, p86, p74, p62, p50,p38),
Koerper(p58,p67,p79, p90, p100,p108,p102,p93, p81, p70,p58),
Koerper(p64,p76,p87, p98, p106,p111,p104,p95, p85, p73,p64),
Koerper(p83,p94,p103,p110,p115,p117,p113,p107,p99, p89,p83),
Koerper(p92,p97,p105,p112,p116,p119,p118,p114,p109,p101,p92)
] 

seiten_liste = [vierecke[i] for i in range(len(vierecke))] + [sechsecke[i] for i in range(len(sechsecke))] + \
               [zehnecke[i] for i in range(len(zehnecke))]

# %%
K = Körper(*seiten_liste, seiten=True)

# %%
sicht_box(-1.2, 1.2)
zeichne(K)

# %%
KS = K.seiten

# %%
K1  = Körper(*[KS[i] for i in range(len(KS)) if KS[i].anz_ecken == 4], seiten=True)   
K2  = Körper(*[KS[i] for i in range(len(KS)) if KS[i].anz_ecken == 6], seiten=True)
K3  = Körper(*[KS[i] for i in range(len(KS)) if KS[i].anz_ecken == 10], seiten=True)

# %%
sicht_box(-2, 2)     # längere Rechenzeit
zeichne([K1, rot, 'fuell=ja'], [K2, gruen, 'fuell=ja'], [K3, gelb, 'fuell=ja'], K, achsen=False, box=False)
